# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv(r"C:\Users\user\Documents\Database Kementrian Desa dan Transmigrasi\Data Cleaning Permukiman - permukiman.csv")

# %%
df.head()
# Out:
#   KODE PROV        NAMA PROVINSI KODE KAB NAMA KABUPATEN KODE KEC  \
# 0         A  NUSA TENGGARA TIMUR      AA1          NGADA    AA101
# 1         A  NUSA TENGGARA TIMUR      AA1          NGADA    AA101
# 2         A  NUSA TENGGARA TIMUR      AA1          NGADA    AA101
# 3         A  NUSA TENGGARA TIMUR      AA1          NGADA    AA101
# 4         A  NUSA TENGGARA TIMUR      AA1          NGADA    AA101
#
#   NAMA KECAMATAN  KODE DESA  Data Tahun Cara_AirMn             BAB  \
# 0         GOLEWA  AA1012002        2023     Gratis  Jamban Sendiri
# 1         GOLEWA  AA1012010        2023     Gratis  Jamban Sendiri
# 2         GOLEWA  AA1012011        2023    Membeli  Jamban Sendiri
# 3         GOLEWA  AA1012018        2023    Membeli  Jamban Sendiri
# 4         GOLEWA  AA1012025        2023     Gratis  Jamban Sendiri
#
#    JmlKK_listrikPLN  JmlKK_listrikNonPLN  KK_nonListrik  \
# 0               292                    0              0
# 1               168                    0              0
# 2               213                    0             39
# 3               170                    9             13
# 4               260                    3              0
#
#    Jlh_RT_Belum_alir_Listrik Terdapat_PJU sumber_pju        Sinyal   Internet  \
# 0                        2.0         Ada         PLN   Sinyal Kuat  Tidak Ada
# 1                        0.0         Ada         PLN   Sinyal Kuat        Ada
# 2                       39.0         Ada         PLN   Sinyal Kuat        Ada
# 3                       33.0         Ada         PLN  Sinyal Lemah        Ada
# 4                        3.0    Tidak Ada  Tidak Ada   Sinyal Kuat        Ada
#
#   Jaringan_Internet_Ktr_Desa Warga_akses_internet
# 0                     4G LTE            Tidak Ada
# 1                     4G LTE                  Ada
# 2                     4G LTE                  Ada
# 3                  Tidak Ada            Tidak Ada
# 4                     4G LTE                  Ada

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   KODE PROV                   1102 non-null   object
#  1   NAMA PROVINSI               1102 non-null   object
#  2   KODE KAB                    1102 non-null   object
#  3   NAMA KABUPATEN              1102 non-null   object
#  4   KODE KEC                    1102 non-null   object
#  5   NAMA KECAMATAN              1102 non-null   object
#  6   KODE DESA                   1102 non-null   object
#  7   Data Tahun                  1102 non-null   int64
#  8   Cara_AirMn                  1102 non-null   object
#  9   BAB                         1102 non-null   object
#  10  JmlKK_listrikPLN            1102 non-null   int64
#  11  JmlKK_listrikNonPLN         1102 non-null   int64
#  12  KK_nonListrik               1102 non-null   int64
#  13  Jlh_RT_Belum_alir_Listrik   1002 non-null   float64
#  14  Terdapat_PJU                1102 non-null   object
#  15  sumber_pju                  1102 non-null   object
#  16  Sinyal                      1102 non-null   object
#  17  Internet                    1102 non-null   object
#  18  Jaringan_Internet_Ktr_Desa  1019 non-null   object
#  19  Warga_akses_internet        1102 non-null   object
# dtypes: float64(1), int64(4), object(15)
# memory usage: 172.3+ KB

# %%
print(df.isnull().sum())
# Out:
# KODE PROV                       0
# NAMA PROVINSI                   0
# KODE KAB                        0
# NAMA KABUPATEN                  0
# KODE KEC                        0
# NAMA KECAMATAN                  0
# KODE DESA                       0
# Data Tahun                      0
# Cara_AirMn                      0
# BAB                             0
# JmlKK_listrikPLN                0
# JmlKK_listrikNonPLN             0
# KK_nonListrik                   0
# Jlh_RT_Belum_alir_Listrik     100
# Terdapat_PJU                    0
# sumber_pju                      0
# Sinyal                          0
# Internet                        0
# Jaringan_Internet_Ktr_Desa     83
# Warga_akses_internet            0
# dtype: int64

# %%
(df.isnull().sum()/len(df)*100).to_frame('persentase missing')
# Out:
#                             persentase missing
# KODE PROV                              0.00000
# NAMA PROVINSI                          0.00000
# KODE KAB                               0.00000
# NAMA KABUPATEN                         0.00000
# KODE KEC                               0.00000
# NAMA KECAMATAN                         0.00000
# KODE DESA                              0.00000
# Data Tahun                             0.00000
# Cara_AirMn                             0.00000
# BAB                                    0.00000
# JmlKK_listrikPLN                       0.00000
# JmlKK_listrikNonPLN                    0.00000
# KK_nonListrik                          0.00000
# Jlh_RT_Belum_alir_Listrik              9.07441
# Terdapat_PJU                           0.00000
# sumber_pju                             0.00000
# Sinyal                                 0.00000
# Internet                               0.00000
# Jaringan_Internet_Ktr_Desa             7.53176
# Warga_akses_internet                   0.00000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=True)
plt.title('Heatmap Missing Value')
plt.show()

# %%
modus_belum_alir_listrik = df['Jlh_RT_Belum_alir_Listrik'].mode()
print(modus_belum_alir_listrik)
df['Jlh_RT_Belum_alir_Listrik'] = df['Jlh_RT_Belum_alir_Listrik'].fillna(0.0)
# Out:
# 0    0.0
# Name: Jlh_RT_Belum_alir_Listrik, dtype: float64

# %%
print(df['Jlh_RT_Belum_alir_Listrik'].isnull().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   KODE PROV                   1102 non-null   object
#  1   NAMA PROVINSI               1102 non-null   object
#  2   KODE KAB                    1102 non-null   object
#  3   NAMA KABUPATEN              1102 non-null   object
#  4   KODE KEC                    1102 non-null   object
#  5   NAMA KECAMATAN              1102 non-null   object
#  6   KODE DESA                   1102 non-null   object
#  7   Data Tahun                  1102 non-null   int64
#  8   Cara_AirMn                  1102 non-null   object
#  9   BAB                         1102 non-null   object
#  10  JmlKK_listrikPLN            1102 non-null   int64
#  11  JmlKK_listrikNonPLN         1102 non-null   int64
#  12  KK_nonListrik               1102 non-null   int64
#  13  Jlh_RT_Belum_alir_Listrik   1102 non-null   float64
#  14  Terdapat_PJU                1102 non-null   object
#  15  sumber_pju                  1102 non-null   object
#  16  Sinyal                      1102 non-null   object
#  17  Internet                    1102 non-null   object
#  18  Jaringan_Internet_Ktr_Desa  1102 non-null   object
#  19  Warga_akses_internet        1102 non-null   object
# dtypes: float64(1), int64(4), object(15)
# memory usage: 172.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
varObjects = df.select_dtypes(include = ['object'])
varObjects.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
for col in varObjects.columns:
    df[col] = df[col].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   KODE PROV                   1102 non-null   category
#  1   NAMA PROVINSI               1102 non-null   category
#  2   KODE KAB                    1102 non-null   category
#  3   NAMA KABUPATEN              1102 non-null   category
#  4   KODE KEC                    1102 non-null   category
#  5   NAMA KECAMATAN              1102 non-null   category
#  6   KODE DESA                   1102 non-null   category
#  7   Data Tahun                  1102 non-null   int64
#  8   Cara_AirMn                  1102 non-null   category
#  9   BAB                         1102 non-null   category
#  10  JmlKK_listrikPLN            1102 non-null   int64
#  11  JmlKK_listrikNonPLN         1102 non-null   int64
#  12  KK_nonListrik               1102 non-null   int64
#  13  Jlh_RT_Belum_alir_Listrik   1102 non-null   float64
#  14  Terdapat_PJU                1102 non-null   category
#  15  sumber_pju                  1102 non-null   category
#  16  Sinyal                      1102 non-null   category
#  17  Internet                    1102 non-null   category
#  18  Jaringan_Internet_Ktr_Desa  1102 non-null   category
#  19  Warga_akses_internet        1102 non-null   category
# dtypes: category(15), float64(1), int64(4)
# memory usage: 117.8 KB

# %%
df.describe(include ="all")
# Out:
#        KODE PROV NAMA PROVINSI KODE KAB   NAMA KABUPATEN KODE KEC  \
# count       1102          1102     1102             1102     1102
# unique         8             8       25               25      181
# top            A        MALUKU      CC1  HALMAHERA BARAT    CC101
# freq         231           231       84               84       21
# mean         NaN           NaN      NaN              NaN      NaN
# std          NaN           NaN      NaN              NaN      NaN
# min          NaN           NaN      NaN              NaN      NaN
# 25%          NaN           NaN      NaN              NaN      NaN
# 50%          NaN           NaN      NaN              NaN      NaN
# 75%          NaN           NaN      NaN              NaN      NaN
# max          NaN           NaN      NaN              NaN      NaN
#
#        NAMA KECAMATAN  KODE DESA  Data Tahun Cara_AirMn             BAB  \
# count            1102       1102      1102.0       1102            1102
# unique            181       1102         NaN          2               4
# top           JAILOLO  AA1012002         NaN     Gratis  Jamban Sendiri
# freq               21          1         NaN        897             862
# mean              NaN        NaN      2023.0        NaN             NaN
# std               NaN        NaN         0.0        NaN             NaN
# min               NaN        NaN      2023.0        NaN             NaN
# 25%               NaN        NaN      2023.0        NaN             NaN
# 50%               NaN        NaN      2023.0        NaN             NaN
# 75%               NaN        NaN      2023.0        NaN             NaN
# max               NaN        NaN      2023.0        NaN             NaN
#
#         JmlKK_listrikPLN  JmlKK_listrikNonPLN  KK_nonListrik  \
# count        1102.000000          1102.000000    1102.000000
# unique               NaN                  NaN            NaN
# top                  NaN                  NaN            NaN
# freq                 NaN                  NaN            NaN
# mean          192.460073            23.064428      48.529946
# std           371.389163            79.106514     233.210929
# min             0.000000             0.000000       0.000000
# 25%            20.000000             0.000000       0.000000
# 50%           112.000000             0.000000       5.000000
# 75%           224.750000            12.000000      31.750000
# max          6445.000000          2000.000000    6000.000000
#
#         Jlh_RT_Belum_alir_Listrik Terdapat_PJU sumber_pju        Sinyal  \
# count                 1102.000000         1102       1102          1102
# unique                        NaN            2          3             3
# top                           NaN    Tidak Ada  Tidak Ada  Sinyal Lemah
# freq                          NaN          596        596           506
# mean                    26.941016          NaN        NaN           NaN
# std                     54.526058          NaN        NaN           NaN
# min                      0.000000          NaN        NaN           NaN
# 25%                      0.000000          NaN        NaN           NaN
# 50%                      6.000000          NaN        NaN           NaN
# 75%                     26.000000          NaN        NaN           NaN
# max                    444.000000          NaN        NaN           NaN
#
#          Internet Jaringan_Internet_Ktr_Desa Warga_akses_internet
# count        1102                       1102                 1102
# unique          2                          5                    2
# top     Tidak Ada                  Tidak Ada                  Ada
# freq          772                        615                  582
# mean          NaN                        NaN                  NaN
# std           NaN                        NaN                  NaN
# min           NaN                        NaN                  NaN
# 25%           NaN                        NaN                  NaN
# 50%           NaN                        NaN                  NaN
# 75%           NaN                        NaN                  NaN
# max           NaN                        NaN                  NaN

# %%
catVar = df.select_dtypes(include = ['object', 'category'])
numVar = df.select_dtypes(include = ['int', 'float'])

# %%
import matplotlib.pyplot as plt, seaborn as sns
import numpy as np
plt.style.use('bmh'); sns.color_palette("tab20"); sns.set()

# Menghitung jumlah baris dan kolom subplot
num_variables = len(catVar.columns)
num_cols = 3  # Sesuaikan sesuai kebutuhan
num_rows = int(np.ceil(num_variables / num_cols))

# Membuat grid countplot dengan Seaborn
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(25, 5 * num_rows))

# Menggunakan Seaborn untuk membuat countplot dalam grid
for i, ax in enumerate(axes.flatten()):
    if i < num_variables:
        col = catVar.columns[i]
        if catVar[col].dtype == 'bool':
            sns.countplot(y=col, data=catVar.astype({col: 'object'}), ax=ax, order=catVar.iloc[:, i].value_counts(ascending=False).index)
        else:
            sns.countplot(y=col, data=catVar, ax=ax, order=catVar.iloc[:, i].value_counts(ascending=False).index)
        ax.set_title(col)
    else:
        fig.delaxes(ax)

# Mengatur layout
plt.tight_layout()
plt.show()

# %%
df.to_csv("C:\\Users\\user\\Documents\\Database Kementrian Desa dan Transmigrasi\\data_bersih_permukiman.csv",index = False)
