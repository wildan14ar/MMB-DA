# %% [markdown]
# # **Hello Python**

# %% [markdown]
# <left> <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e2/Guido-portrait-2014-drc.jpg/1200px-Guido-portrait-2014-drc.jpg" width=350>

# %% [markdown]
# > **Python** adalah salah satu bahasa pemrograman yang sedang naik daun. Kepopulerannya terus meroket sejak tahun 2010. Python menjadi bahasa pemrograman yang mudah untuk dipelajari, termasuk bagi orang-orang yang baru belajar bahasa pemrograman.
#
# > Kemudian apa yang membuat Python begitu populer? Beberapa diantaranya adalah:
# 1. Python adalah **general multipurpose programming**. Artinya, dengan bahasa pemrograman Python, kita hampir bisa membuat berbagai macam aplikasi, contohnya web, desktop, game, dan lain sebagainya.
# 2. Python **mudah untuk dipelajari**. Python didesain dengan penekanan agar mudah untuk dibaca. Kita bisa menuangkan konsep aplikasi kita kedalam bahasa python dengan baris yang relatif sedikit, sehingga kita bisa lebih cepat dan efektif dalam membangun suatu aplikasi.
# 3. Python **open source**. Artinya, python gratis dan setiap orang bisa berkontribusi untuk perkembangan python dan membagikannya ke orang lain.

# %% [markdown]
# # **Syntax**

# %% [markdown]
# * Case Sensitive, contoh: "Python" != "python"
# * interpreter & Compiler
# * Tidak perlu tanda ; diakhir code
# * tidak perlu curly bracket {}, melainkan menggunakan tab (4 space) untuk definisi function

# %% [markdown]
# ## Basic Syntax

# %% [markdown]
# ### 1. Penulisan Statement Python
# Statement adalah sebuah intruksi atau kalimat perintah yang akan dieksekusi oleh komputer.

# %%
print("Hello World!")
print("Belajar Python dari Nol")

nama = "Belajar Python"
# Out:
# Hello World!
# Belajar Python dari Nol

# %%
print(nama)
# Out:
# Belajar Python

# %% [markdown]
# Penulisan satu statement tidak diakhiri dengan tanda titik-koma.
#
# Sedangkan, bila kita ingin menulis lebih dari satu statement dalam satu baris, maka kita harus memisahnya dengan titik-koma.

# %%
print("Hello"); print("World"); print("Tutorial Python untuk Pemula")

nama_depan = "Lukman"; nama_belakang = "Hakim"
# Out:
# Hello
# World
# Tutorial Python untuk Pemula

# %%
print(nama_depan)
print(nama_belakang)
# Out:
# Lukman
# Hakim

# %% [markdown]
# Tapi…
#
# Menurut beberapa style guide python, tidak dianjurkan menulis lebih dari satu statement dalam satu baris. Karena akan sulit dibaca.

# %% [markdown]
# ### 2. Penulisan String pada Python
#
# String adalah teks atau kumpulan dari karakter.
#
# String dalam pemrograman biasanya ditulis dengan dibungkus menggunakan tanda petik.
#
# Bisa menggunakan tanda petik tunggal maupun ganda.

# %%
judul = "3"
penulis = 'Kim Mingyu'

# %%
print(judul)
print(penulis)
# Out:
# 3
# Kim Mingyu

# %% [markdown]
# kita dapat menggunakan 3 tanda petik untuk menuliskan string

# %%
judul = 'Belajar "Python" sampai bisa'
penulis = '''"Kim Mingyu"'''

# %%
print(judul)
print(penulis)
# Out:
# Belajar "Python" sampai bisa
# "Kim Mingyu"

# %% [markdown]
# ### 3. Penulisan Case pada Python
#
# Sintak Python bersifat case sensitive, artinya teksini dengan TeksIni dibedakan.

# %%
judul = "Belajar Dasa-dasar Python"
Judul = "Belajar Membuat Program Python"

# %% [markdown]
# antara variabel judul dan Judul itu berbeda

# %%
print(judul)
print(Judul)
# Out:
# Belajar Dasa-dasar Python
# Belajar Membuat Program Python

# %% [markdown]
# Case Style
#
# Menurut rekomendasi [Style guide Google](https://google.github.io/styleguide/pyguide.html), berikut ini contoh penulisan case yang disarankan:

# %% [markdown]
# **Snake_Case digunakan pada** :
# module_name, package_name, method_name, function_name, global_var_name, instance_var_name, function_parameter_name, local_var_name.
#
# **CamelCase digunakan Pada**:
# ClassName, ExceptionName, LocalVarName
#
# **ALL CAPS digunakan Pada**:
# GLOBAL_CONSTANT_NAME

# %% [markdown]
# ### 4. Penulisan Blok Program Python
#
# **Blok program** adalah kumpulan dari beberpaa statement yang digabungkan dalam satu blok.
#
# Penulisan blok program harus ditambahkan indentasi (tab atau spasi 2x/4x).

# %% [markdown]
# ![fig-2-5-2-blok-kode-python.png](data:image/png;base64,...)

# %% [markdown]
# Ada beberapa macam blok program:
# * Blok Percabangan
# * Blok Perulangan
# * Blok Fungsi
# * Blok Class
# * Blok Exception
# * Blok With

# %% [markdown]
# ### 5. Penulisan Komentar pada Python

# %% [markdown]
# **Komentar** merupakan baris kode yang tidak akan dieksekusi. Komentar digunakan untuk memberikan informasi tambahan dan untuk menonaktifkan kode.

# %% [markdown]
# **Menggunakan Tanda Pagar (#)**

# %%
# ini adalah komentar
# Ini juga komentar
"""komentar"""
# Out:
# 'komentar'

# %%
# Block Code untuk menghitung luas segitiga
t = 10 # t adalah tinggi segitiga
a = 6 # a adalah alas segitiga
luas_segitiga = 0.5*a*t # ini adalah rumus untuk menghitung luas segitiga
print(luas_segitiga) # menampilkan hasil perhitungan luas segitiga
# Out:
# 30.0

# %%
print(judul)
# Out:
# Belajar Dasa-dasar Python

# %% [markdown]
# **Menggunakan Tanda Petik**
#
# Selain untuk mengapit teks (string), tanda petik juga dapat digunakan untuk membuat komentar.

# %%
"Ini adalah komentar dengan tanda petik ganda"
'Ini juga komentar, tapi dengan tanda petik tunggal'
a = 'itulah cara berkomentar'

# %% [markdown]
# Penulisan komentar dengan tanda petik jarang digunakan, kebanyakan orang lebih memilih untuk menggunakan tanda pagar. Jadi…tidak direkomendasikan HEHEHE

# %% [markdown]
# # **Variabel**

# %% [markdown]
# > Variabel adalah lokasi memori yang dicadangkan untuk menyimpan nilai-nilai. Ini berarti bahwa ketika Anda membuat sebuah variabel Anda memesan beberapa ruang di memori. Variabel menyimpan data yang dilakukan selama program dieksekusi, yang nantinya isi dari variabel tersebut dapat diubah oleh operasi - operasi tertentu pada program yang menggunakan variabel.
#
# > Variabel dapat menyimpan berbagai macam tipe data. Di dalam pemrograman Python, variabel mempunyai sifat yang dinamis, artinya variabel Python tidak perlu didekralasikan tipe data tertentu dan variabel Python dapat diubah saat program dijalankan.
#
# > Penulisan variabel Python sendiri juga memiliki aturan tertentu, yaitu :
#
# 1. Karakter pertama harus berupa huruf atau garis bawah/underscore _
# 2. Karakter selanjutnya dapat berupa huruf, garis bawah/underscore _ atau angka
# 3. Karakter pada nama variabel bersifat sensitif (case-sensitif). Artinya huruf kecil dan huruf besar dibedakan. Sebagai contoh, variabel namaDepan dan namadepan adalah variabel yang berbeda.
#
# > Untuk mulai membuat variabel di Python caranya sangat mudah, Anda cukup menuliskan variabel lalu mengisinya dengan suatu nilai dengan cara menambahkan tanda sama dengan = diikuti dengan nilai yang ingin dimasukan

# %%
#proses memasukan data ke dalam variabel
nama = "John Doe"
#proses mencetak variabel
print(nama)
# Out:
# John Doe

# %%
#nilai dan tipe data dalam variabel dapat diubah
umur = 20 #nilai awal
print(umur) #mencetak nilai umur
type(umur) #mengecek tipe data umur
# Out:
# 20
# int

# %%
Umur = "dua puluh satu" #nilai setelah diubah
print(umur) #mencetak nilai umur
type(umur) #mengecek tipe data umur
# Out:
# 20
# int

# %%
print(umur)
# Out:
# 20

# %%
namaDepan = "Budi"
namaBelakang = "Susanto"
nama = namaDepan + " " + namaBelakang
umur = 22
hobi = "Berenang"
print("Biodata\n", 'nama : ', nama, "\n", 'umur : ', umur, "\n", 'hobi : ', hobi)
# Out:
# Biodata
#  nama :  Budi Susanto
#  umur :  22
#  hobi :  Berenang

# %%
print(f"nama: {namaDepan} {namaBelakang}")
# Out:
# nama: Budi Susanto

# %%
#contoh variabel lainya
#inivariabel = "Halo" (TIDAK ERROR)
#ini_juga_variabel = "Hai" (TIDAK ERROR)
#\_inivariabeljuga = "Hi" (ERROR)
#inivariabel222 = "Bye" (TIDAK ERROR)
#2variable = 'haihai' (ERROR)
#.variable = 'okeoke' (ERROR)
#var/a = 'ayee' (ERROR)
# Out:
#   File "<ipython-input-36-4f63a326a92f>", line 8
#     var/a = 'ayee'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
panjang = 10
lebar = 5
luas = panjang * lebar
print(luas)
# Out:
# 50

# %% [markdown]
# # **Tipe Data**

# %% [markdown]
# Tipe Data merupakan klasifikasi data yang memberi tahu interpreter bagaimana programmer akan menggunakan datanya. Tipe data dalam Python seperti berikut:
#
# 1. Tunggal
# * **Numerik** : Integer (Bilangan Bulat) dan Float (Bilangan Desimal)
# * **String** : (Huruf/kata/kalimat)
# * **Boolean** : (True or False)
#
# 2. Jamak
# * **Lists** (kumpulan elemen yang dapat diubah)
# * **Dictionaries** (sekumpulan key dan value)
# * **Sets** (himpunan)
# * **Tuples** (kumpulan elemen yang tidak dapat diubah)

# %% [markdown]
# ![tipe-data.png](data:image/png;base64,...)

# %% [markdown]
# source : belajarpython.com

# %%
#tipe data Boolean

print(True)
print(False)
# Out:
# True
# False

# %%
#tipe data String

print("Ayo belajar Python")
print('Belajar Python Sangat Mudah')
# Out:
# Ayo belajar Python
# Belajar Python Sangat Mudah

# %%
#tipe data Integer

print(20)
# Out:
# 20

# %%
#tipe data Float

print(3.14)
# Out:
# 3.14

# %%
print(3/4)
# Out:
# 0.75

# %%
#tipe data List

print([1,2,3,4,5])
print(["satu", "dua", "tiga"])
# Out:
# [1, 2, 3, 4, 5]
# ['satu', 'dua', 'tiga']

# %%
#tipe data Tuple

tup = (1,2,3,4,5)
print((1,2,3,4,5))
print(("satu", "dua", "tiga"))
# Out:
# (1, 2, 3, 4, 5)
# ('satu', 'dua', 'tiga')

# %%
print(type([1,2,3,4,5]))
# Out:
# <class 'list'>

# %%
#tipe data Dictionary
print({"nama":"Budi", 'umur':20})

#tipe data Dictionary dimasukan ke dalam variabel biodata
biodata = {"nama":"Andi", 'umur':21} #proses inisialisasi variabel biodata

print(biodata) #proses pencetakan variabel biodata yang berisi tipe data Dictionary
print(type(biodata)) #fungsi untuk mengecek jenis tipe data. akan tampil <class 'dict'> yang berarti dict adalah tipe data dictionary
# Out:
# {'nama': 'Budi', 'umur': 20}
# {'nama': 'Andi', 'umur': 21}
# <class 'dict'>

# %% [markdown]
# # **Operator**

# %% [markdown]
# **Operator** adalah konstruksi yang dapat memanipulasi nilai dari operan. Sebagai contoh operasi 3 + 2 = 5. Disini 3 dan 2 adalah operan dan + adalah operator.
#
# Bahasa pemrograman Python mendukung berbagai macam operator, diantaranya :
# 1. Operator Aritmatika (Arithmetic Operators)
# 2. Operator Perbandingan (Comparison (Relational) Operators)
# 3. Operator Penugasan (Assignment Operators)
# 4. Operator Logika (Logical Operators)
# 5. Operator Bitwise (Bitwise Operators)
# 6. Operator Keanggotaan (Membership Operators)
# 7. Operator Identitas (Identity Operators)

# %% [markdown]
# ### Operator Aritmatika

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 10
b = 4
c = 18

print(a+b)
# Out:
# 14

# %%
a-b
# Out:
# 6

# %%
a*b
# Out:
# 40

# %%
c/a
# Out:
# 1.8

# %%
c%b
# Out:
# 2

# %%
c**a
# Out:
# 3570467226624

# %%
c//a
# Out:
# 1

# %%
c*b-a+b/3%5//3
# Out:
# 62.0

# %%
a = 'aku'
b = 'makan'
c = 'kamu'

# %%
print(a+b)
# Out:
# akumakan

# %%
print(a-b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-b6199382ecad> in <cell line: 1>()
# ----> 1 print(a-b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
print(a*b*c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-879221736afa> in <cell line: 1>()
# ----> 1 print(a*b*c)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print(a*2)
# Out:
# akuaku

# %% [markdown]
# ### Operator Perbandingan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 2
b = 4
c = 2

# %%
a == b
# Out:
# False

# %%
a == c
# Out:
# True

# %%
a != b
# Out:
# True

# %%
a != c
# Out:
# False

# %%
a >= b
# Out:
# False

# %%
a = 'sapi'
b = 'beli'
c = 'sapi'

# %%
a = 'a'
b = 'b'

# %%
a == b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a != b
# Out:
# True

# %% [markdown]
# ### Operator Penugasan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 2
b = 3
c = 4

# %%
a += b
a
# Out:
# 5

# %%
a *= c
a
# Out:
# 20

# %%
c -= a
c
# Out:
# -16

# %%
c **= b
c
# Out:
# -4096

# %%
a = 'apel'
b = 'kambing'
c = 'langit'

# %%
a += c
a
# Out:
# 'apellangit'

# %%
a -= c
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-b971e36a7f7b> in <cell line: 1>()
# ----> 1 a -= c
#       2 a
#
# TypeError: unsupported operand type(s) for -=: 'str' and 'str'
